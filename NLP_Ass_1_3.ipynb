# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a54123-web/NLP/blob/main/NLP_Ass_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy

# %%
import nltk
import spacy

# %%
text = """Natural Language Processing is a branch of Artificial Intelligence.
It helps computers understand human language."""

# %%
words = text.split()
word_count = len(words)

print("Number of words:", word_count)
# Out:
# Number of words: 15

# %%
lower_text = text.lower()
print(lower_text)
# Out:
# natural language processing is a branch of artificial intelligence.
# it helps computers understand human language.
